# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasVale98/Formacao_Data_Science/blob/main/Data_Visualization_cria%C3%A7%C3%A3o_de_gr%C3%A1ficos_com_o_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **01. Primeira Visualização**

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/datasets/alura_curssos/Data Visualization criação de gráficos com o Matplotlib'
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Fazendo as primeiras visualizações**

# %%
import pandas as pd

# %%
dados = pd.read_csv(path + '/monitoramento_tempo.csv')

# %%
dados.head()
# Out:
#    temperatura  pressão  ...  dia_da_semana                 data
# 0   282.080000   1024.0  ...        Domingo  2012-10-01 12:00:00
# 1   282.080000   1024.0  ...        Domingo  2012-10-01 13:00:00
# 2   282.083252   1024.0  ...        Domingo  2012-10-01 14:00:00
# 3   282.091866   1024.0  ...        Domingo  2012-10-01 15:00:00
# 4   282.100481   1024.0  ...        Domingo  2012-10-01 16:00:00
#
# [5 rows x 7 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
dados["data"] = pd.to_datetime(dados["data"])

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 2.4+ MB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(dados["data"], dados["temperatura"])

# %%
plt.figure(figsize=(15,8))
plt.plot(dados["data"], dados["temperatura"])

# %%
plt.figure(figsize=(15,8))
plt.plot(dados["data"], dados["temperatura"])
plt.title("Temperatura no Tempo")
# Out:
# Text(0.5, 1.0, 'Temperatura no Tempo')

# %% [markdown]
# **Funcionalidades básicas do matplotlib**

# %%
plt.figure(figsize=(15,8))
plt.plot(dados["data"], dados["temperatura"])
plt.title("Temperatura no Tempo")
plt.ylabel("Temperaturas")
plt.xlabel("Anos")
# Out:
# Text(0.5, 0, 'Anos')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(dados['data'], dados['temperatura'])

eixo.set_title('Temperatura no momento')
# Out:
# Text(0.5, 1.0, 'Temperatura no momento')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(dados['data'], dados['temperatura'])

eixo.set_title('Temperatura no momento')
eixo.set_ylabel("Temperatura")
eixo.set_xlabel("Data")
# Out:
# Text(0.5, 0, 'Data')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(dados['data'], dados['temperatura'])

eixo.set_title('Temperatura no momento', fontsize=30)
eixo.set_ylabel("Temperatura", fontsize=18)
eixo.set_xlabel("Data", fontsize=18)
# Out:
# Text(0.5, 0, 'Data')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(dados['data'], dados['temperatura'])

eixo.set_title('Temperatura no momento', fontsize=30)
eixo.set_ylabel("Temperatura", fontsize=18)
eixo.set_xlabel("Data", fontsize=18)
eixo.legend(["Temperatura"], loc= "lower right", fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(dados['data'], dados['temperatura'], color="green")

eixo.set_title('Temperatura no momento', fontsize=30)
eixo.set_ylabel("Temperatura", fontsize=18)
eixo.set_xlabel("Data", fontsize=18)
eixo.legend(["Temperatura"], loc= "lower right", fontsize=15)

# %% [markdown]
# # **02. Customizando nossas visualizações**

# %% [markdown]
# **Espessura, estilo, foco, marcadores e grades**

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(dados['data'], dados['temperatura'], color="g", lw=4)

eixo.set_title('Temperatura no momento', fontsize=30)
eixo.set_ylabel("Temperatura", fontsize=18)
eixo.set_xlabel("Data", fontsize=18)
eixo.legend(["Temperatura"], loc= "lower right", fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(dados['data'], dados['temperatura'], color="g", lw=0.4)

eixo.set_title('Temperatura no momento', fontsize=30)
eixo.set_ylabel("Temperatura", fontsize=18)
eixo.set_xlabel("Data", fontsize=18)
eixo.legend(["Temperatura"], loc= "lower right", fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(dados['data'], dados['temperatura'], color="g", ls="dotted")

eixo.set_title('Temperatura no momento', fontsize=30)
eixo.set_ylabel("Temperatura", fontsize=18)
eixo.set_xlabel("Data", fontsize=18)
eixo.legend(["Temperatura"], loc= "lower right", fontsize=15)

# %%
import datetime

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(dados['data'], dados['temperatura'], color="g")

eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title('Temperatura no momento', fontsize=30)
eixo.set_ylabel("Temperatura", fontsize=18)
eixo.set_xlabel("Data", fontsize=18)
eixo.legend(["Temperatura"], loc= "lower right", fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(dados['data'], dados['temperatura'], color="g", marker="o")

eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title('Temperatura no momento', fontsize=30)
eixo.set_ylabel("Temperatura", fontsize=18)
eixo.set_xlabel("Data", fontsize=18)
eixo.legend(["Temperatura"], loc= "lower right", fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(dados['data'], dados['temperatura'], color="g")

eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title('Temperatura no momento', fontsize=30)
eixo.set_ylabel("Temperatura", fontsize=18)
eixo.set_xlabel("Data", fontsize=18)
eixo.legend(["Temperatura"], loc= "lower right", fontsize=15)
eixo.grid(True)

# %% [markdown]
# **Mais de um eixo na mesma visualização**

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])

eixo.grid(True)
eixo.plot(dados["data"], dados["temperatura"], color="g")

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])

eixo.grid(True)
eixo.plot(dados["data"], dados["temperatura"], color="g")
eixo.set_title("Temperatura no momento", fontsize=30, pad=20)
eixo.legend(["Temperatura"], loc="best", fontsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])

eixo.grid(True)
eixo.plot(dados["data"], dados["temperatura"], color="g")
eixo.set_title("Temperatura no momento", fontsize=30, pad=20)
eixo.set_ylabel("Temperatura")
eixo.set_ylabel("Data")
eixo.legend(["Temperatura"], loc="best", fontsize=15)


eixo2.grid(True)
eixo2.plot(dados["data"], dados["temperatura"], color="b")
eixo2.set_title("Temperatura no momento", fontsize=15)
eixo2.set_ylabel("Temperatura")
eixo2.set_ylabel("Data")
eixo2.legend(["Temperatura"], loc="best", fontsize=8)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(dados["data"], dados["temperatura"], color="g")
eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title("Temperatura em 2014", fontsize=30, pad=20)
eixo.set_ylabel("Temperatura")
eixo.set_ylabel("Data")
eixo.legend(["Temperatura"], loc="lower right", fontsize=15)

eixo2.grid(True)
eixo2.plot(dados["data"], dados["temperatura"], color="b")
eixo2.set_title("Temperatura no momento", fontsize=15)
eixo2.set_ylabel("Temperatura")
eixo2.set_ylabel("Data")
eixo2.legend(["Temperatura"], loc="best", fontsize=8)

# %% [markdown]
# **Uma visualização mais complexa**

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(dados["data"], dados["temperatura"], color="g")
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
eixo.set_title("Temperatura em 2014", fontsize=30, pad=20)
eixo.set_ylabel("Temperatura")
eixo.set_ylabel("Data")
eixo.legend(["Temperatura"], loc="lower right", fontsize=15)

eixo2.grid(True)
eixo2.plot(dados["data"], dados["temperatura"], color="b")
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.set_title("Temperatura no momento", fontsize=15)
eixo2.set_ylabel("Temperatura")
eixo2.set_ylabel("Data")
eixo2.legend(["Temperatura"], loc="best", fontsize=8)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(dados["data"], dados["temperatura"], color="g")
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
eixo.set_ylim(270, 320)
eixo.set_title("Temperatura em maio/2014", fontsize=30, pad=20)
eixo.set_ylabel("Temperatura")
eixo.set_xlabel("Data")
eixo.legend(["Temperatura"], loc="lower right", fontsize=15)

eixo2.grid(True)
eixo2.plot(dados["data"], dados["temperatura"], color="b")
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.set_title("Temperatura em 2014", fontsize=15)
eixo2.set_ylabel("Temperatura")
eixo2.set_xlabel("Data")
eixo2.legend(["Temperatura"], loc="best", fontsize=8)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(dados["data"], dados["temperatura"], color="g")
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
eixo.set_ylim(270, 320)
eixo.set_title("Temperatura em maio/2014", fontsize=30, pad=20)
eixo.set_ylabel("Temperatura")
eixo.set_xlabel("Data")
eixo.legend(["Temperatura"], loc="lower right", fontsize=15)

azul_esquerda = dados['data'] < datetime.datetime(2014,5,1)
azul_direita = dados['data'] > datetime.datetime(2014,6,1)


eixo2.grid(True)
eixo2.plot(dados['data'], dados['temperatura'], color = 'g')
eixo2.plot(dados[azul_esquerda]['data'], dados[azul_esquerda]['temperatura'], color = 'b')
eixo2.plot(dados[azul_direita]['data'], dados[azul_direita]['temperatura'], color = 'b')
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.set_title("Temperatura em 2014", fontsize=15)
eixo2.set_ylabel("Temperatura")
eixo2.set_xlabel("Data")
eixo2.legend(["Temperatura"], loc="best", fontsize=8)

# %% [markdown]
# # **03.Anotações e diversos gráficos**

# %% [markdown]
# **Linhas de restrição e anotações**

# %%
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(dados['data'], dados['temperatura'], color = 'g')

eixo.set_title('Temperatura no momento', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

eixo.axhline(max(dados["temperatura"]), color="k", linestyle="--")
eixo.axhline(min(dados["temperatura"]), color="k", linestyle="--")

# %%
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(dados['data'], dados['temperatura'], color = 'g')

eixo.set_title('Temperatura no momento', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

x1 = dados['data'][dados['temperatura'].idxmax()]
y1 = max(dados['temperatura'])
eixo.annotate('Máximo', xy=(x1,y1), fontsize=20)

eixo.axhline(max(dados["temperatura"]), color="k", linestyle="--")
eixo.axhline(min(dados["temperatura"]), color="k", linestyle="--")

# %%
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(dados['data'], dados['temperatura'], color = 'g')

eixo.set_title('Temperatura no momento', fontsize = 25, pad = 20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

x1 = dados['data'][dados['temperatura'].idxmax()]
y1 = max(dados['temperatura'])

x2 = dados['data'][dados['temperatura'].idxmax() - 7000]
y2 = max(dados['temperatura']) - 5

eixo.annotate('Máximo', xy=(x1,y1), fontsize=20,
              xytext=(x2,y2), arrowprops=dict(facecolor='k'))

x1 = dados['data'][dados['temperatura'].idxmin()]
y1 = min(dados['temperatura'])

x2 = dados['data'][dados['temperatura'].idxmin() - 7000]
y2 = min(dados['temperatura']) + 5

eixo.annotate('Mínimo', xy=(x1,y1), fontsize=20,
              xytext=(x2,y2), arrowprops=dict(facecolor='k'))

eixo.axhline(max(dados["temperatura"]), color="k", linestyle="--")
eixo.axhline(min(dados["temperatura"]), color="k", linestyle="--")

# %% [markdown]
# **Algumas outras visualizações**

# %%
temperatura_por_dia_da_semana = dados.groupby('dia_da_semana')['temperatura'].mean()
nome_dias = ['Domingo', 'Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado']
temperatura_por_dia_da_semana = temperatura_por_dia_da_semana[nome_dias]
temperatura_por_dia_da_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Segunda    284.985382
# Terça      284.892811
# Quarta     284.998290
# Quinta     285.000643
# Sexta      285.060886
# Sábado     285.003316
# Name: temperatura, dtype: float64

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])
indice = range(len(temperatura_por_dia_da_semana))

eixo.bar(indice, temperatura_por_dia_da_semana)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
# Out:
# Text(0, 0.5, 'Temperatura média')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])
indice = range(len(temperatura_por_dia_da_semana))

eixo.bar(indice, temperatura_por_dia_da_semana)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Segunda'),
#  Text(0, 0, 'Terça'),
#  Text(0, 0, 'Quarta'),
#  Text(0, 0, 'Quinta'),
#  Text(0, 0, 'Sexta'),
#  Text(0, 0, 'Sábado')]

# %% [markdown]
# # **04. Visualizando dados diversos**

# %% [markdown]
# **Utilizando gráficos de dispersão**

# %%
dados = pd.read_csv(path + '/iris.csv')

# %%
dados.head()
# Out:
#    comprimento_sépala  largura_sépala  ...  largura_pétala      espécie
# 0                 5.1             3.5  ...             0.2  Iris-setosa
# 1                 4.9             3.0  ...             0.2  Iris-setosa
# 2                 4.7             3.2  ...             0.2  Iris-setosa
# 3                 4.6             3.1  ...             0.2  Iris-setosa
# 4                 5.0             3.6  ...             0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(dados['comprimento_sépala'], dados['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
# Out:
# Text(0, 0.5, 'Largura da sépala')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(dados['comprimento_sépala'], dados['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=15)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa': 'r', 'Iris-versicolor': 'b', 'Iris-virginica': 'g'}
marcadores = {'Iris-setosa': 'x', 'Iris-versicolor': 'o', 'Iris-virginica': 'v'}

for especie in dados['espécie'].unique():
    tmp = dados[dados['espécie'] == especie]
    eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
                 color=cores[especie], marker=marcadores[especie], s=100)

eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=15)
eixo.legend(cores, fontsize=20)

# %% [markdown]
# **Visualizando a distribuição de dados**

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(dados['largura_pétala'])
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(['largura_pétala'])
# Out:
# [Text(0, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(dados.drop('espécie', axis=1).values)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(dados.drop('espécie', axis=1).columns)
# Out:
# [Text(0, 0, 'comprimento_sépala'),
#  Text(0, 0, 'largura_sépala'),
#  Text(0, 0, 'comprimento_pétala'),
#  Text(0, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize=(8,5))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(dados.drop('espécie', axis=1).values, patch_artist=True)
eixo.set_title('Gráfico de caixa', fontsize=15, pad=10)
eixo.set_xticklabels(dados.drop('espécie', axis=1).columns)
# Out:
# [Text(0, 0, 'comprimento_sépala'),
#  Text(0, 0, 'largura_sépala'),
#  Text(0, 0, 'comprimento_pétala'),
#  Text(0, 0, 'largura_pétala')]
