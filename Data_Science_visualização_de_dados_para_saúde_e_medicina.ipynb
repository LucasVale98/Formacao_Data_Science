# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasVale98/Formacao_Data_Science/blob/main/Data_Science_visualiza%C3%A7%C3%A3o_de_dados_para_sa%C3%BAde_e_medicina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **01. Boletins e explorações**

# %% [markdown]
# **Criando comparações em snapshots**

# %%
import pandas as pd

confirmed = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")
confirmed.head()
# Out:
#   Province/State Country/Region       Lat  ...  2/23/21  2/24/21  2/25/21
# 0            NaN    Afghanistan  33.93911  ...    55646    55664    55680
# 1            NaN        Albania  41.15330  ...   102306   103327   104313
# 2            NaN        Algeria  28.03390  ...   112279   112461   112622
# 3            NaN        Andorra  42.50630  ...    10739    10775    10799
# 4            NaN         Angola -11.20270  ...    20584    20640    20695
#
# [5 rows x 405 columns]

# %%
confirmed.set_index("Country/Region").loc["China"].sum().tail()
# Out:
# 2/21/21    100758
# 2/22/21    100784
# 2/23/21    100807
# 2/24/21    100832
# 2/25/21    100851
# dtype: object

# %%
is_china = confirmed["Country/Region"] == "China"
is_china.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Country/Region, dtype: bool

# %%
confirmed["is_china"] = is_china
display(confirmed.head())
display(confirmed.tail())
# Out:
#   Province/State Country/Region       Lat  ...  2/24/21  2/25/21  is_china
# 0            NaN    Afghanistan  33.93911  ...    55664    55680     False
# 1            NaN        Albania  41.15330  ...   103327   104313     False
# 2            NaN        Algeria  28.03390  ...   112461   112622     False
# 3            NaN        Andorra  42.50630  ...    10775    10799     False
# 4            NaN         Angola -11.20270  ...    20640    20695     False
#
# [5 rows x 406 columns]
#     Province/State      Country/Region        Lat  ...  2/24/21  2/25/21  is_china
# 269            NaN             Vietnam  14.058324  ...     2412     2421     False
# 270            NaN  West Bank and Gaza  31.952200  ...   177768   179293     False
# 271            NaN               Yemen  15.552727  ...     2221     2255     False
# 272            NaN              Zambia -13.133897  ...    76484    77171     False
# 273            NaN            Zimbabwe -19.015438  ...    35960    35994     False
# ...

# %%
confirmed.query("is_china")
# Out:
#     Province/State Country/Region      Lat  ...  2/24/21  2/25/21  is_china
# 58           Anhui          China  31.8257  ...      994      994      True
# 59         Beijing          China  40.1824  ...     1047     1047      True
# 60       Chongqing          China  30.0572  ...      591      591      True
# 61          Fujian          China  26.0789  ...      549      549      True
# 62           Gansu          China  35.7518  ...      187      187      True
# 63       Guangdong          China  23.3417  ...     2198     2200      True
# 64         Guangxi          China  23.8298  ...      267      267      True
# 65         Guizhou          China  26.8154  ...      147      147      True
# 66          Hainan          China  19.1959  ...      171      171      True
# 67           Hebei          China  39.5490  ...     1317     1317      True
# 68    Heilongjiang          China  47.8620  ...     1610     1610      True
# ...

# %%
confirmed.groupby("is_china").sum()
# Out:
#                  Lat         Long  1/22/20  ...    2/23/21    2/24/21    2/25/21
# is_china                                    ...
# False     4520.70925  2597.745414        9  ...  112008946  112453469  112900561
# True      1085.29230  3688.937700      548  ...     100807     100832     100851
#
# [2 rows x 403 columns]

# %%
confirmed.groupby("is_china").sum()["2/25/21"].plot(kind="bar")

# %% [markdown]
# **Evolução em time series copy**

# %%
import numpy as np

# %%
confirmed["is_china_label"] = np.where(confirmed["is_china"], "China", "Others")
display(confirmed.head())
display(confirmed.tail())
# Out:
#   Province/State Country/Region       Lat  ...  2/25/21  is_china  is_china_label
# 0            NaN    Afghanistan  33.93911  ...    55680     False          Others
# 1            NaN        Albania  41.15330  ...   104313     False          Others
# 2            NaN        Algeria  28.03390  ...   112622     False          Others
# 3            NaN        Andorra  42.50630  ...    10799     False          Others
# 4            NaN         Angola -11.20270  ...    20695     False          Others
#
# [5 rows x 407 columns]
#     Province/State      Country/Region  ...  is_china  is_china_label
# 269            NaN             Vietnam  ...     False          Others
# 270            NaN  West Bank and Gaza  ...     False          Others
# 271            NaN               Yemen  ...     False          Others
# 272            NaN              Zambia  ...     False          Others
# 273            NaN            Zimbabwe  ...     False          Others
#
# [5 rows x 407 columns]

# %%
confirmed.groupby("is_china_label").sum()["2/25/21"].plot(kind="bar")

# %%
confirmed.groupby("is_china_label").sum().T[2:-2].plot()

# %% [markdown]
# **02. Junrnado bases**

# %% [markdown]
# **Taxa de Incidencia**

# %%
population = pd.read_csv("https://population.un.org/wpp/Download/Files/1_Indicators%20(Standard)/CSV_FILES/WPP2019_TotalPopulationBySex.csv")

# %%
population["PopTotal"] = population["PopTotal"] * 1000
population.head()
# Out:
#    LocID     Location  VarID  ... PopFemale   PopTotal  PopDensity
# 0      4  Afghanistan      2  ...  3652.874  7752117.0      11.874
# 1      4  Afghanistan      2  ...  3705.395  7840151.0      12.009
# 2      4  Afghanistan      2  ...  3761.546  7935996.0      12.156
# 3      4  Afghanistan      2  ...  3821.348  8039684.0      12.315
# 4      4  Afghanistan      2  ...  3884.832  8151316.0      12.486
#
# [5 rows x 10 columns]

# %% [markdown]
# **Juntando datasets distintos e buscando dados nas nações unidas**

# %%
population.query("Time == 2019")[["Location", "PopTotal"]].set_index("Location")
# Out:
#                                                   PopTotal
# Location
# Afghanistan                                   3.804176e+07
# Africa                                        1.308064e+09
# African Group                                 1.306321e+09
# African Union                                 1.306903e+09
# African Union: Central Africa                 1.540137e+08
# ...                                                    ...
# World                                         7.713468e+09
# World Bank Regional Groups (developing only)  6.452517e+09
# Yemen                                         2.916192e+07
# Zambia                                        1.786103e+07
# Zimbabwe                                      1.464547e+07
#
# [477 rows x 1 columns]
